# %% [markdown]
# # Import thư viện

# %%
import os
import string

# %% [markdown]
# # Import nguồn ảnh

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bb_path = "/content/drive/MyDrive/Collab/data/original_data"
labeled_path = "/content/drive/MyDrive/Collab/data/labeled_data"

# %% [markdown]
# # Đọc file .txt

# %%
class_list = ['BEANS', 'CAKE', 'CANDY', 'CEREAL', 'CHIPS', 'CHOCOLATE', 'COFFEE', 'CORN', 'FISH',
              'FLOUR', 'HONEY', 'JAM', 'JUICE', 'MILK', 'NUTS', 'OIL', 'PASTA', 'RICE', 'SODA',
              'SPICES', 'SUGAR', 'TEA', 'TOMATO_SAUCE', 'VINEGAR', 'WATER']

# %%
file_dir = os.path.join (bb_path, "labels")
for file_name in os.listdir (file_dir):
  print (file_name)
  file = open(os.path.join(file_dir, file_name), "r")
  str = file.read()
  print(str,'\n')
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 0 0.555814 0.508945 0.368515 0.527728
#
# JUICE0029.txt
# 0 0.468157 0.497317 0.590340 0.550984
#
# HONEY0057.txt
# 0 0.441536 0.405759 0.527051 0.595113
# 0 0.486038 0.832461 0.476440 0.335078
# 0 0.854276 0.650087 0.280977 0.469459
#
# HONEY0044.txt
# 0 0.426702 0.531414 0.469459 0.626527
# 0 0.829843 0.520070 0.340314 0.722513
# 0 0.093368 0.706806 0.186736 0.328098
# 0 0.107330 0.631763 0.197208 0.310646
#
# JUICE0006.txt
# 0 0.260644 0.501789 0.307692 0.574240
# 0 0.559392 0.421288 0.211091 0.413238
# 0 0.786583 0.492844 0.329159 0.559928
# 0 0.098748 0.432916 0.169946 0.443649
# 0 0.384079 0.424866 0.139535 0.427549
#
# HONEY0058.txt
# 0 0.602967 0.575916 0.406632 0.624782
# 0 0.363002 0.473822 0.363002 0.497382
# 0 0.081152 0.546248 0.158813 0.506108
# 0 0.287086 0.089878 0.232112 0.176265
# 0 0.510471 0.084642 0.183246 0.162304
# 0 0.729494 0.431937 0.268761 0.448517
# 0 0.958988 0.422339 0.082024 0.439791
#
# ...

# %%
file_dir = os.path.join (bb_path, "labels")

for file_name in os.listdir (file_dir):

  # Đọc file
  print (file_name)
  file = open(os.path.join(file_dir, file_name), "r")
  str = file.read()
  print(str,'\n')

  # Gắn lại nhãn
  for i in range (1, 24):
    if class_list[i] in file.name:
      new_label = "{}".format(i) + " "
      data_new = data.replace ("0 ", new_label)
  print(data_new,'\n')

  # Ghi lại file
  file = open(os.path.join(file_dir, file_name), "w")
  file.write(data_new)
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 20 0.581152 0.212914 0.600349 0.087260
#
# OIL0052.txt
# 15 0.5436315 0.474695 0.9127415 0.471204
# 15 0.581152 0.212914 0.600349 0.087260
#
# 15 0.5436315 0.474695 0.9127415 0.471204
# 15 0.581152 0.212914 0.600349 0.087260
#
# JAM0031.txt
# 11 0.5436311 0.474695 0.9127411 0.471204
# 11 0.581152 0.212914 0.600349 0.087260
#
# 11 0.5436311 0.474695 0.9127411 0.471204
# 11 0.581152 0.212914 0.600349 0.087260
#
# SUGAR0010.txt
# 20 0.5436320 0.474695 0.9127420 0.471204
# 20 0.581152 0.212914 0.600349 0.087260
#
# 20 0.5436320 0.474695 0.9127420 0.471204
# 20 0.581152 0.212914 0.600349 0.087260
#
# JAM0030.txt
# 11 0.5436311 0.474695 0.9127411 0.471204
# 11 0.581152 0.212914 0.600349 0.087260
#
# 11 0.5436311 0.474695 0.9127411 0.471204
# 11 0.581152 0.212914 0.600349 0.087260
#
# SUGAR0008.txt
# 20 0.5436320 0.474695 0.9127420 0.471204
# 20 0.581152 0.212914 0.600349 0.087260
#
# 20 0.5436320 0.474695 0.9127420 0.471204
# ...
